# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:/Machine learning buffalo/wdbc.csv",header=None)

# %%
df.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9    ...        22     23      24      25      26      27      28  \
# 0  0.14710   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %%
df.drop(0,axis=1,inplace=True)

# %%
df[1]=df[1].map({'M':1, 'B':0})

# %%
df.head()
# Out:
#    1      2      3       4       5        6        7       8        9   \
# 0   1  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710
# 1   1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017
# 2   1  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790
# 3   1  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520
# 4   1  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430
#
#        10   ...        22     23      24      25      26      27      28  \
# 0  0.2419   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.1812   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.2069   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.2597   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.1809   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %%
Traindf,Testdf=train_test_split(df, test_size = 0.1,random_state=1)
Traindf,Valdf=train_test_split(df,test_size=0.1,random_state=1)

# %%
train_x= Traindf[Traindf.loc[:,Traindf.columns!=1].columns]
train_y=Traindf[Traindf.loc[:,Traindf.columns==1].columns]
test_x=Testdf[Testdf.loc[:,Testdf.columns!=1].columns]
test_y=Testdf[Testdf.loc[:,Testdf.columns==1].columns]
vald_x=Valdf[Valdf.loc[:,Valdf.columns!=1].columns]
vald_y=Valdf[Valdf.loc[:,Valdf.columns==1].columns]

train_x=np.asarray(train_x)
train_y=np.asarray(train_y)
test_x=np.asarray(test_x)
test_y =np.asarray(test_y)
vald_x=np.asarray(vald_x)
vald_y=np.asarray(vald_y)


training=classification(train_x.T,train_y.T,epochs=10,learning_rate=0.01)
w=training["w"]
b=training["b"]
costs=training["costs"]
plt.plot(costs)
plt.title("Cost vs #Iterations")
plt.xlabel("Number of Iterations ( * 10)")
plt.ylabel("Cost")

Predict_train=predict(train_x.T,w,b)
predict_val=predict(vald_x.T,w,b)
print("training accuracy:{}%".format(100-np.mean(np.abs(predict_train-train_x.T))*100))
print("validation accuracy:{}%".format(100-np.mean(np.abs(predict_val-vald_x.T))*100))
# Out:
# cost after 0 iteration :0.693147
# C:\Users\DELL\Anaconda3.5.2.0\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in exp
#
# C:\Users\DELL\Anaconda3.5.2.0\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
# C:\Users\DELL\Anaconda3.5.2.0\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in multiply
#   from ipykernel import kernelapp as app
# cost after 1 iteration :nan
# cost after 2 iteration :nan
# cost after 3 iteration :nan
# cost after 4 iteration :nan
# cost after 5 iteration :nan
# cost after 6 iteration :nan
# cost after 7 iteration :nan
# cost after 8 iteration :nan
# cost after 9 iteration :nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-aa34105424c5> in <module>()
# ...

# %%
X.shape
# Out:
# (30, 512)

# %%
target.shape
# Out:
# (512, 1)

# %%
target.head()
# Out:
#      1
# 277  1
# 378  0
# 547  0
# 159  0
# 9    1

# %%
X.head()
# Out:
#         2      3       4       5        6        7        8         9   \
# 277  18.81  19.98  120.90  1102.0  0.08923  0.05884  0.08020  0.058430
# 378  13.66  15.15   88.27   580.6  0.08268  0.07548  0.04249  0.024710
# 547  10.26  16.58   65.85   320.8  0.08877  0.08066  0.04358  0.024380
# 159  10.90  12.96   68.69   366.8  0.07515  0.03718  0.00309  0.006588
# 9    12.46  24.04   83.97   475.9  0.11860  0.23960  0.22730  0.085430
#
#          10       11   ...        22     23      24      25      26       27  \
# 277  0.1550  0.04996   ...     19.96  24.30  129.00  1236.0  0.1243  0.11600
# 378  0.1792  0.05897   ...     14.54  19.64   97.96   657.0  0.1275  0.31040
# 547  0.1669  0.06714   ...     10.83  22.04   71.08   357.4  0.1461  0.22460
# 159  0.1442  0.05743   ...     12.36  18.20   78.07   470.0  0.1171  0.08294
# 9    0.2030  0.08243   ...     15.09  40.68   97.65   711.4  0.1853  1.05800
#
#           28       29      30       31
# ...

# %%
X.shape
# Out:
# (30, 512)

# %%
target.shape
# Out:
# (512, 1)

# %%
#create the weight function

    

def sigmoid(X):
    return 1/(1+np.exp(-X))    

def optimize(X,target,W,b,epochs,learning_rate):
    costs=[]
    for i in range(epochs):
        for j in range(epochs):
            m=X.shape[1]
            z=np.dot(W.T,X)+b   
            a=sigmoid(z)
            cost= -(1/m)*np.sum(target*np.log(a)+(1-target)*np.log(1-a))
            dw=(1/m)*np.dot(X,(target-a.T))
            db=(1/m)*np.sum(target-a)
   # losstrack.append(np.squeeze())
        W=W-learning_rate*dw
        b=b-learning_rate*db
        costs.append(cost)
        print("cost after %i iteration :%f" %(i,cost))
    parameter={"w":W,"b":b}
    grads={"dw":dw,"db":db}
    plt.plot(costs)
    plt.title("cost vs epochs")
    plt.xlabel("number of epochs")
    plt.ylabel("cost")
    return parameter,grads,costs
        
        #plt.plot(losstrack)
def classification(X,target,epochs,learning_rate):
   
    learning_rate=0.01 
    b = 0
    W=np.zeros((X.shape[0],1))
    parameters,grads,costs=optimize(X,target,W,b,epochs,learning_rate)
    W=parameters["w"]
    b=parameters["b"]
    d={"w":W,"b":b,"costs":costs}
    return d  

def predict(X,w,b):
    m=X.shape[1]
    print(w)
    target_value=np.zeros((1,m))
    w=w.reshape(X.shape[0],1)
    P=sigmoid(np.dot(w.T,X)+b)
    for i in range (P.shape[1]):
        if(P[0,i]<0.5):
            target_value[0,i]=0
        else:
            target_value[0,i]=1
    
    return target_value

# %%
m=X.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-37cd159fa45d> in <module>()
# ----> 1 m=X.shape[1]
#
# NameError: name 'X' is not defined

# %%
m
# Out:
# 512

# %%
m=X.shape[0]

# %%
m
# Out:
# 30
